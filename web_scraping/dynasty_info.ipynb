# %%
import pandas as pd

# %%
data = [
    {
        "name": "Japan",
        "start_year": "660 BC",
        "end_year": "Continue",
        "house": "Yamato",
        "current_country": "Japan"
    },
    {
        "name": "Joseon",
        "start_year": "1392",
        "end_year": "1897",
        "house": "Yi",
        "current_country": "N/S Korea"
    },
    {
        "name": "Goryeo",
        "start_year": "918",
        "end_year": "1392",
        "house": "Wang",
        "current_country": "N/S Korea"
    },
    {
        "name": "Han",
        "start_year": "202 BC",
        "end_year": "220",
        "house": "Liu",
        "current_country": "China"
    },
    {
        "name": "Sui",
        "start_year": "581",
        "end_year": "618",
        "house": "Yang",
        "current_country": "China"
    },
    {
        "name": "Tang",
        "start_year": "618",
        "end_year": "907",
        "house": "Li",
        "current_country": "China"
    },
    {
        "name": "Song",
        "start_year": "960",
        "end_year": "1279",
        "house": "Zhao",
        "current_country": "China"
    },
    {
        "name": "Ming",
        "start_year": "1368",
        "end_year": "1644",
        "house": "Zhu",
        "current_country": "China"
    },
    {
        "name": "Qing",
        "start_year": "1636",
        "end_year": "1912",
        "house": "Aisin Gioro",
        "current_country": "China"
    },
]

dynasties_dict = {
    "name": [],
    "start_year": [],
    "end_year": [],
    "house": [],
    "current_country": [],
}

# %%
for dynasty in data:
    dynasties_dict["name"].append(dynasty["name"])
    dynasties_dict["start_year"].append(dynasty["start_year"])
    dynasties_dict["end_year"].append(dynasty["end_year"])
    dynasties_dict["house"].append(dynasty["house"])
    dynasties_dict["current_country"].append(dynasty["current_country"])

# %%
df = pd.DataFrame(dynasties_dict)
df
# Out:
#      name start_year  end_year        house current_country
# 0   Japan     660 BC  Continue       Yamato           Japan
# 1  Joseon       1392      1897           Yi       N/S Korea
# 2  Goryeo        918      1392         Wang       N/S Korea
# 3     Han     202 BC       220          Liu           China
# 4     Sui        581       618         Yang           China
# 5    Tang        618       907           Li           China
# 6    Song        960      1279         Zhao           China
# 7    Ming       1368      1644          Zhu           China
# 8    Qing       1636      1912  Aisin Gioro           China

# %%
df.to_csv("dynasty.csv")

# %%
dynasties_dict["name"]
# Out:
# ['Japan', 'Joseon', 'Goryeo', 'Han', 'Sui', 'Tang', 'Song', 'Ming', 'Qing']
