# %% [markdown]
# # Web Scraping

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# #### Extracting one dynasty

# %%
URL = "https://en.wikipedia.org/wiki/Timeline_of_the_Han_dynasty"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
tables = soup.find_all("table", class_="wikitable")

# %%
tables[1]
# Out:
# <table class="wikitable" style="width:100%;">
# <tbody><tr>
# <th style="width:6%">Year</th>
# <th style="width:10%">Date</th>
# <th>Event
# </th></tr>
# <tr>
# <td>197 BC</td>
# <td></td>
# <td>The <a href="/wiki/Xiongnu" title="Xiongnu">Xiongnu</a> invade <a href="/wiki/Dai_Commandery" title="Dai Commandery">Dai Commandery</a> with the help of <a href="/wiki/Chen_Xi_(rebel)" title="Chen Xi (rebel)">Chen Xi</a> and <a class="mw-redirect" href="/wiki/Xin,_King_of_Han" title="Xin, King of Han">Han Xin</a><sup class="reference" id="cite_ref-FOOTNOTEChang2007143_4-0"><a href="#cite_note-FOOTNOTEChang2007143-4">[4]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2" style="vertical-align:top;">196 BC</td>
# <td></td>
# <td><a href="/wiki/Emperor_Gaozu_of_Han" title="Emperor Gaozu of Han">Emperor Gaozu of Han</a> replaces nine of the ten <a href="/wiki/Kings_of_the_Han_dynasty" title="Kings of the Han dynasty">Kings of the Han dynasty</a> with his brothers and sons<sup class="reference" id="cite_ref-FOOTNOTETwitchett2008124_5-0"><a href="#cite_note-FOOTNOTETwitchett2008124-5">[5]</a></sup>
# </td></tr>
# <tr>
# <td></td>
# <td>The <a href="/wiki/Xiongnu" title="Xiongnu">Xiongnu</a> invade <a href="/wiki/Dai_Commandery" title="Dai Commandery">Dai Commandery</a> with the help of <a class="mw-redirect" href="/wiki/Xin,_King_of_Han" title="Xin, King of Han">Han Xin</a><sup class="reference" id="cite_ref-FOOTNOTEChang2007143_4-1"><a href="#cite_note-FOOTNOTEChang2007143-4">[4]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2" style="vertical-align:top;">195 BC</td>
# <td>1 June</td>
# <td><a href="/wiki/Emperor_Gaozu_of_Han" title="Emperor Gaozu of Han">Emperor Gaozu of Han</a> dies and is succeeded by Liu Ying (posthumously <a href="/wiki/Emperor_Hui_of_Han" title="Emperor Hui of Han">Emperor Hui of Han</a>)<sup class="reference" id="cite_ref-FOOTNOTETwitchett2008130_6-0"><a href="#cite_note-FOOTNOTETwitchett2008130-6">[6]</a></sup>
# </td></tr>
# <tr>
# <td></td>
# <td>The <a href="/wiki/Xiongnu" title="Xiongnu">Xiongnu</a> invade <a class="mw-redirect" href="/wiki/You_Prefecture" title="You Prefecture">You Province</a> with the help of <a href="/wiki/Lu_Wan" title="Lu Wan">Lu Wan</a><sup class="reference" id="cite_ref-FOOTNOTETwitchett2008124_5-1"><a href="#cite_note-FOOTNOTETwitchett2008124-5">[5]</a></sup>
# </td></tr></tbody></table>

# %%
data = []
count = 0
previous_year_value = -1
old_year_value = -1
def add_row_data(table):
    row_data = {}
    for tr in table.tbody.find_all("tr"):
        td = tr.find_all("td")
        data_row_length = len(td)  
        # there is two cases: data rows is 3 or 2 (where the column is expanded)
        if data_row_length == 3:
            # td[0].getText() is the value from the year column
            # td[2].text is the value from the event column
            # we can skip the date column
            year = td[0].getText().replace("\\n", "").strip()
            if year == "":
                year = previous_year_value
            previous_year_value = year
            sup = td[2].find("sup")
            if sup:
                sup.extract()
            content = td[2].text.replace("\\n", "").strip()
            row_data[year] = []
            row_data[year].append(content)
            old_year_value = td[0].text
            
        elif data_row_length == 2: 
            # old_year_value will have the value of the latest key from row_data
            # so we can do this directly
            sup = td[1].find("sup")
            if sup:
                sup.extract()
            content = td[1].text.replace("\\n", "").strip()
            row_data[old_year_value].append(content)
            previous_year_value = old_year_value
    return row_data

# %%
def convert_year_period(year):
    addition = {
        "1": "st century",
        "2": "nd century",
        "3": "rd century",
        "4": "th century"
    }
    process_year = year.split(" ")
    # len(process_year) == 2 => Always BC
    # len(process_year) == 1 => It is always AD
    century = str(int(process_year[0]) // 100 + 1)
    get_addition = addition.get(century[-1]) if century[-1] == "1" or century[-1] == "2" or century[-1] == "3" else addition["4"]
    
    if len(process_year) == 2:
        return str(century) + get_addition + " " + "BC"
    elif len(process_year) == 1:
        return str(century) + get_addition

# %%
add_row_data(tables[6])
# Out:
# {'1636': ['Hong Taiji proclaims the Qing dynasty',
#   'Qing invasion of Joseon: Hong Taiji invades Joseon'],
#  '1637': ['Qing invasion of Joseon: Joseon is defeated and becomes a Qing tributary'],
#  '1638': ['Qing dynasty conquers Shandong'],
#  '1639': ['Qing dynasty attacks the Daur and Solon people']}

# %%
# titles: remember that now titles is a list of title such as 3rd Century BC
data_dict = {
    "year": [],
    "description": [],
    "period": [],
    "current_country": [],
    "country": []
}

COUNTRY = "China"
country_name = "Han"
idx_title = 0
for table in tables:
    table_data = add_row_data(table)
    for key in table_data:
        for content in table_data[key]:
            data_dict["year"].append(key)
            data_dict["description"].append(content)
            data_dict["period"].append(convert_year_period(key))
            data_dict["current_country"].append(COUNTRY)
            data_dict["country"].append(country_name)
    idx_title += 1

# %%
df = pd.DataFrame(data_dict)
df
# Out:
#        year                                        description  \
# 0    202 BC  Liu Bang becomes emperor of the Han dynasty (p...
# 1    202 BC  Emperor Gaozu of Han moves the capital from Lu...
# 2    201 BC  Battle of Baideng: Emperor Gaozu of Han's army...
# 3    201 BC            Xin, King of Han defects to the Xiongnu
# 4    197 BC  The Xiongnu invade Dai Commandery with the hel...
# ..      ...                                                ...
# 248     219  Lü Meng's invasion of Jing Province: Sun Quan'...
# 249     220                    Guan Yu is executed by Sun Quan
# 250     220  Cao Cao dies at Luoyang and is succeeded by hi...
# 251     220                The Nine-rank system is implemented
# 252     220  Cao Pi forces Emperor Xian of Han to abdicate ...
#
#              period current_country country
# 0    3rd century BC           China     Han
# 1    3rd century BC           China     Han
# 2    3rd century BC           China     Han
# 3    3rd century BC           China     Han
# 4    2nd century BC           China     Han
# ..              ...             ...     ...
# 248     3rd century           China     Han
# 249     3rd century           China     Han
# 250     3rd century           China     Han
# 251     3rd century           China     Han
# 252     3rd century           China     Han
#
# [253 rows x 5 columns]

# %%
df[df["year"]=="65 BC"]
# Out:
#      year                                        description          period  \
# 97  65 BC  Han forces under Feng Fenshi force the king of...  1st century BC
# 98  65 BC                               Han vassalizes Qiuci  1st century BC
# 99  65 BC                  The Qiang revolt in eastern Tibet  1st century BC
#
#    current_country country
# 97           China     Han
# 98           China     Han
# 99           China     Han

# %%
convert_year_period("202 BC")
# Out:
# '3rd century BC'

# %%
df.isnull().sum()
# Out:
# year               0
# description        0
# period             0
# current_country    0
# country            0
# dtype: int64

# %%
# df.to_csv("china.csv")

# %% [markdown]
# ### Testing with another dynasty

# %%
URL = "https://en.wikipedia.org/wiki/Timeline_of_the_Sui_dynasty"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
tables = soup.find_all("table", class_="wikitable")

# %%
data_dict = {
    "year": [],
    "description": [],
    "period": [],
    "current_country": [],
    "country": []
}

COUNTRY = "China"
country_name = "Sui"
idx_title = 0
for table in tables:
    table_data = add_row_data(table)
    for key in table_data:
        for content in table_data[key]:
            data_dict["year"].append(key)
            data_dict["description"].append(content)
            data_dict["period"].append(convert_year_period(key))
            data_dict["current_country"].append(COUNTRY)
            data_dict["country"].append(country_name)
    idx_title += 1

# %%
df = pd.DataFrame(data_dict)
df
# Out:
#    year                                        description       period  \
# 0   581  Yang Jian (Emperor Wen of Sui) replaces the No...  6th century
# 1   582  Emperor Xuan of Chen dies and is succeeded by ...  6th century
# 2   583  Emperor Wen of Sui moves into Daxingcheng (Xi'...  6th century
# 3   584                           Digs the Guangtong Canal  6th century
# 4   587                              Annexes Western Liang  6th century
# 5   588       Launches expedition against the Chen dynasty  6th century
# 6   589  Takes Jiankang and annexes the Chen dynasty; s...  6th century
# 7   590  Yang Su crushes rebellions in annexed Chen ter...  6th century
# 8   592  Emperor Wen of Sui sends out commissioners to ...  6th century
# 9   593                        The Cuanman rebel in Yunnan  6th century
# 10  593    The Renshou Palace is built west of the capital  6th century
# 11  593  The writing of National Histories by private i...  6th century
# 12  594  Severe drought hits Guanzhong but Emperor Wen ...  6th century
# 13  595             Construction of the Anji Bridge begins  6th century
# 14  597                    Tiantai sect founder Zhiyi dies  6th century
# 15  597         A campaign is launched against the Cuanman  6th century
# 16  598  Goguryeo–Sui War: First expedition against Gog...  6th century
# 17  599         Chief minister Gao Jiong deprived of power  6th century
# 18  599               Yami Qaghan flees to the Sui dynasty  6th century
# 19  601                                90,000 Turks submit  7th century
# 20  602  Sui–Former Lý War: Sui forces under Liu Fang a...  7th century
# 21  602                           Sui destroys the Cuanman  7th century
# 22  603  Yami Qaghan takes over Tulan Qaghan's lands af...  7th century
# 23  604  Emperor Wen of Sui dies and is succeeded by Ya...  7th century
# 24  604      Yang Liang rebels in Bingzhou but is defeated  7th century
# 25  605  Sui forces under Liu Fang invade Champa and sa...  7th century
# 26  605  Construction of a new Luoyang and the Tongji C...  7th century
# 27  605                       The Anji Bridge is completed  7th century
# 28  605                 Emperor Yang of Sui visits Jiangdu  7th century
# 29  606  Luoyang is completed and Emperor Yang of Sui r...  7th century
# 30  607  Yami Qaghan visits Emperor Yang of Sui in Luoyang  7th century
# 31  607                                Gao Jiong is killed  7th century
# 32  607                          Ono no Imoko visits China  7th century
# 33  607  The Sui dynasty sends expeditions to an island...  7th century
# 34  608                            The Yongji Canal is dug  7th century
# 35  608  Pei Shiqing accompanies Ono no Imoko back to J...  7th century
# 36  609                 Emperor Yang of Sui visits Zhangye  7th century
# 37  610                 Emperor Yang of Sui visits Jiangdu  7th century
# 38  610          Construction of the Jiangnan Canal begins  7th century
# 39  611  Goguryeo–Sui War: Emperor Yang of Sui arrives ...  7th century
# 40  611  Wang Bo (王薄) rebels in Changbaishan (Zouping, ...  7th century
# 41  612   Goguryeo–Sui War: The invasion of Goguryeo fails  7th century
# 42  613  Goguryeo–Sui War: Emperor Yang of Sui is force...  7th century
# 43  613                      Du Fuwei and Fu Gongshi rebel  7th century
# 44  614           Goguryeo–Sui War: Another invasion fails  7th century
# 45  615                    Shibi Khan lays siege to Yanmen  7th century
# 46  616             Emperor Yang of Sui leaves for Jiangdu  7th century
# 47  617  Li Mi and Zhai Rang rebel, seizing Luokou Gran...  7th century
# 48  617  Li Yuan, regent of Taiyuan, rebels and takes D...  7th century
# 49  618  Emperor Yang of Sui is killed by strangulation...  7th century
# 50  618  Li Yuan (Tang Gaozu - note that Tang emperor n...  7th century
#
#    current_country country
# 0            China     Sui
# 1            China     Sui
# 2            China     Sui
# 3            China     Sui
# 4            China     Sui
# 5            China     Sui
# 6            China     Sui
# 7            China     Sui
# 8            China     Sui
# 9            China     Sui
# 10           China     Sui
# 11           China     Sui
# 12           China     Sui
# 13           China     Sui
# 14           China     Sui
# 15           China     Sui
# 16           China     Sui
# 17           China     Sui
# 18           China     Sui
# 19           China     Sui
# 20           China     Sui
# 21           China     Sui
# 22           China     Sui
# 23           China     Sui
# 24           China     Sui
# 25           China     Sui
# 26           China     Sui
# 27           China     Sui
# 28           China     Sui
# 29           China     Sui
# 30           China     Sui
# 31           China     Sui
# 32           China     Sui
# 33           China     Sui
# 34           China     Sui
# 35           China     Sui
# 36           China     Sui
# 37           China     Sui
# 38           China     Sui
# 39           China     Sui
# 40           China     Sui
# 41           China     Sui
# 42           China     Sui
# 43           China     Sui
# 44           China     Sui
# 45           China     Sui
# 46           China     Sui
# 47           China     Sui
# 48           China     Sui
# 49           China     Sui
# 50           China     Sui

# %% [markdown]
# ### To events.csv

# %%
['Japan', 'Joseon', 'Goryeo', 'Han', 'Sui', 'Tang', 'Song', 'Ming', 'Qing']
# Out:
# ['Japan', 'Joseon', 'Goryeo', 'Han', 'Sui', 'Tang', 'Song', 'Ming', 'Qing']

# %%
dynasties = {
    "3": "https://en.wikipedia.org/wiki/Timeline_of_the_Han_dynasty",
    "4": "https://en.wikipedia.org/wiki/Timeline_of_the_Sui_dynasty",
    "5": "https://en.wikipedia.org/wiki/Timeline_of_the_Tang_dynasty",
    "6": "https://en.wikipedia.org/wiki/Timeline_of_the_Song_dynasty#:~:text=The%20Song%20dynasty%20is%20commonly,dynasty%20(1115%E2%80%931234).",
    "7": "https://en.wikipedia.org/wiki/Timeline_of_the_Ming_dynasty",
    "8": "https://en.wikipedia.org/wiki/Timeline_of_the_Qing_dynasty"   
}

# %%
data_dict = {
    "year": [],
    "description": [],
    "period": [],
    "dynasty_id": []
    }

for dynasty in dynasties:
    URL = dynasties[dynasty]
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    tables = soup.find_all("table", class_="wikitable")
    idx_title = 0
    for table in tables:
        table_data = add_row_data(table)
        for key in table_data:
            for content in table_data[key]:
                data_dict["year"].append(key)
                data_dict["description"].append(content)
                data_dict["period"].append(convert_year_period(key))
                data_dict["dynasty_id"].append(dynasty)
        idx_title += 1

# %%
df = pd.DataFrame(data_dict)
df
# Out:
#         year                                        description  \
# 0     202 BC  Liu Bang becomes emperor of the Han dynasty (p...
# 1     202 BC  Emperor Gaozu of Han moves the capital from Lu...
# 2     201 BC  Battle of Baideng: Emperor Gaozu of Han's army...
# 3     201 BC            Xin, King of Han defects to the Xiongnu
# 4     197 BC  The Xiongnu invade Dai Commandery with the hel...
# ...      ...                                                ...
# 1847    1907  The territories of Manchuria are reorganized i...
# 1848    1907  Anhui governor Enming is assassinated by the a...
# 1849    1907  Empress Dowager Cixi declares her intention to...
# 1850    1907  An edict is passed to disband provincial banne...
# 1851    1907  An edict is passed to create a set of codes wh...
#
#               period dynasty_id
# 0     3rd century BC          3
# 1     3rd century BC          3
# 2     3rd century BC          3
# 3     3rd century BC          3
# 4     2nd century BC          3
# ...              ...        ...
# 1847    20th century          8
# 1848    20th century          8
# 1849    20th century          8
# 1850    20th century          8
# 1851    20th century          8
#
# [1852 rows x 4 columns]

# %%
df.to_csv("china.csv", mode='a', header=False)

# %%
df.to_csv("events.csv", mode='a', header=False)
